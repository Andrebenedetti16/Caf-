# %%
# %%writefile cafe.csv
# dia, venda
# 1, 29.99
# 2, 34.99
# 3, 32.74
# 4, 31.90
# 5, 37.98
# 6, 39.98
# Out:
# Writing cafe.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df_cafe = pd.read_csv("cafe.csv")

plt.figure(figsize=(10,6))
sns.lineplot(data=df_cafe, x='dia', y=' venda')
plt.title("Preço do Café em Campinas (Junho de 2025)")
plt.xlabel("Dia de Junho")
plt.ylabel("Preço Médio(R$)")
plt.grid(True)
plt.savefig('cafe.png')
